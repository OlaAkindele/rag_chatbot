# %% [markdown]
# # RAG CHATBOT RESPONSES EVALUATION

# %% [markdown]
# #### QUERY, RETRIEVER, AND CHATBOT RESPONSES
#
# Note that all proprietary details have been asterisk (*), removed or obfuscated

# %%
Query1 = 'Could you please provide an overview of the topics discussed during the pull tester training?'

Chatbot_output1 = """
                      **************************
                  """

database_retriever1 = """
                        *************************
                      """

# %%
Query2 = 'What was the main discussion in the email ID *******'

Chatbot_output2 = """
                      **************************
                  """

database_retriever2 = """
                        *************************
                      """

# %%
Query3 = "Could you provide all the information regarding the email with the subject ************** ?"

Chatbot_output1 = """
                      **************************
                  """

database_retriever1 = """
                        *************************
                      """

# %%
Query4 = "What was the primary content of discussion in email ID **********"

Chatbot_output1 = """
                      **************************
                  """

database_retriever1 = """
                        *************************
                      """

# %%
Query5 = 'Could you please provide information in the email with the revision ID ******?'

Chatbot_output1 = """
                     The revision with the ID ******* pertains to an email sent by  **************************
                  """

database_retriever1 = """
                        *************************
                      """

# %% [markdown]
# #### Load OpenAI key

# %%
# !pip install -q openai python-dotenv pandas

# run to load environment variables from a .env file.
# This is not required if you have exported env variables
from dotenv import load_dotenv
load_dotenv()
import os
import pandas as pd

import openai
from openai import OpenAI


# Set the OpenAI API key env variable manually
os.environ["OPENAI_API_KEY"] = "******"

print(os.environ["OPENAI_API_KEY"])

client = OpenAI()
# Out:
# sk-proj-aYWTt3D8AuoAE9x1COb3T3BlbkFJgaRDqnlKRRQBVWmjqEOJ

# %% [markdown]
# ### Bert Score

# %%
# !pip install -q bert-score pandas numpy
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 97.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 84.9 MB/s eta 0:00:00

# %%
from bert_score import score

# %% [markdown]
# ## Summarisation Quality Evaluation

# %% [markdown]
# ### BERTScore

# %%
from bert_score import BERTScorer

# Function to calculate BERT scores
def calculate_bert_scores(botOutput, retrieval):
    # Instantiate the BERTScorer object for English language
    scorer = BERTScorer(lang="en")
    precision, recall, f_score = scorer.score([botOutput], [retrieval])
    # return f_score.tolist()[0]
    return precision, recall, f_score

print('BERTScore:', calculate_bert_scores(Chatbot_output1, database_retriever1))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ...

# %%
print('BERTScore:', calculate_bert_scores(Chatbot_output2, database_retriever2))
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BERTScore: (tensor([0.8883]), tensor([0.8211]), tensor([0.8534]))

# %%
print('BERTScore:', calculate_bert_scores(Chatbot_output3, database_retriever3))
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BERTScore: (tensor([0.8708]), tensor([0.7831]), tensor([0.8247]))

# %%
print('BERTScore:', calculate_bert_scores(Chatbot_output4, database_retriever4))
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BERTScore: (tensor([0.8800]), tensor([0.7935]), tensor([0.8345]))

# %%
print('BERTScore:', calculate_bert_scores(Chatbot_output5, database_retriever5))
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BERTScore: (tensor([0.8653]), tensor([0.7997]), tensor([0.8312]))

# %%
### G-Eval

# %%
# Evaluation prompt template based on G-Eval
EVALUATION_PROMPT_TEMPLATE = """
You will be given one summary written for an article. Your task is to rate the summary on one metric.
Please make sure you read and understand these instructions very carefully.
Please keep this document open while reviewing, and refer to it as needed.

Evaluation Criteria:

{criteria}

Evaluation Steps:

{steps}

Example:

Source Text:

{document}

Summary:

{summary}

Evaluation Form (scores ONLY):

- {metric_name}
"""

# Metric 1: Relevance

RELEVANCY_SCORE_CRITERIA = """
Relevance(1-5) - selection of important content from the source. \
The summary should include only important information from the source document. \
Annotators were instructed to penalize summaries which contained redundancies and excess information.
"""

RELEVANCY_SCORE_STEPS = """
1. Read the summary and the source document carefully.
2. Compare the summary to the source document and identify the main points of the article.
3. Assess how well the summary covers the main points of the article, and how much irrelevant or redundant information it contains.
4. Assign a relevance score from 1 to 5.
"""

# Metric 2: Coherence

COHERENCE_SCORE_CRITERIA = """
Coherence(1-5) - the collective quality of all sentences. \
We align this dimension with the DUC quality question of structure and coherence \
whereby "the summary should be well-structured and well-organized. \
The summary should not just be a heap of related information, but should build from sentence to a\
coherent body of information about a topic."
"""

COHERENCE_SCORE_STEPS = """
1. Read the article carefully and identify the main topic and key points.
2. Read the summary and compare it to the article. Check if the summary covers the main topic and key points of the article,
and if it presents them in a clear and logical order.
3. Assign a score for coherence on a scale of 1 to 5, where 1 is the lowest and 5 is the highest based on the Evaluation Criteria.
"""

# Metric 3: Consistency

CONSISTENCY_SCORE_CRITERIA = """
Consistency(1-5) - the factual alignment between the summary and the summarized source. \
A factually consistent summary contains only statements that are entailed by the source document. \
Annotators were also asked to penalize summaries that contained hallucinated facts.
"""

CONSISTENCY_SCORE_STEPS = """
1. Read the article carefully and identify the main facts and details it presents.
2. Read the summary and compare it to the article. Check if the summary contains any factual errors that are not supported by the article.
3. Assign a score for consistency based on the Evaluation Criteria.
"""

# Metric 4: Fluency

FLUENCY_SCORE_CRITERIA = """
Fluency(1-3): the quality of the summary in terms of grammar, spelling, punctuation, word choice, and sentence structure.
1: Poor. The summary has many errors that make it hard to understand or sound unnatural.
2: Fair. The summary has some errors that affect the clarity or smoothness of the text, but the main points are still comprehensible.
3: Good. The summary has few or no errors and is easy to read and follow.
"""

FLUENCY_SCORE_STEPS = """
Read the summary and evaluate its fluency based on the given criteria. Assign a fluency score from 1 to 3.
"""


def get_geval_score(
    criteria: str, steps: str, document: str, summary: str, metric_name: str
):
    prompt = EVALUATION_PROMPT_TEMPLATE.format(
        criteria=criteria,
        steps=steps,
        metric_name=metric_name,
        document=document,
        summary=summary,
    )
    response = client.chat.completions.create(
        model="gpt-4",
        messages=[{"role": "user", "content": prompt}],
        temperature=0,
        max_tokens=5,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0,
    )
    return response.choices[0].message.content


evaluation_metrics = {
    "Relevance": (RELEVANCY_SCORE_CRITERIA, RELEVANCY_SCORE_STEPS),
    "Coherence": (COHERENCE_SCORE_CRITERIA, COHERENCE_SCORE_STEPS),
    "Consistency": (CONSISTENCY_SCORE_CRITERIA, CONSISTENCY_SCORE_STEPS),
    "Fluency": (FLUENCY_SCORE_CRITERIA, FLUENCY_SCORE_STEPS),
}


# Set the summary
summary = Chatbot_output1

# Define the max score for each metric
max_scores = {
    "Relevance": 5,
    "Coherence": 5,
    "Consistency": 5,
    "Fluency": 3,
}

# Store evaluation data
data = {"Evaluation Type": [], "Score": [], "Normalized Score": []}

# Evaluate the summary on each metric
for eval_type, (criteria, steps) in evaluation_metrics.items():
    data["Evaluation Type"].append(eval_type)
    result = get_geval_score(criteria, steps, database_retriever1, summary, eval_type)
    score_num = int(result.strip())
    max_score = max_scores[eval_type]
    fraction = round(score_num / max_score, 2)

    data["Score"].append(score_num)
    data["Normalized Score"].append(fraction)

# Create a DataFrame
eval_df = pd.DataFrame(data)

# Display results
print("\nG-Eval Evaluation Score :\n")
display(eval_df)
# Out:
# G-Eval Evaluation Score :
#   Evaluation Type  Score  Normalized Score
# 0       Relevance      5               1.0
# 1       Coherence      5               1.0
# 2     Consistency      5               1.0
# 3         Fluency      3               1.0

# %%
# Set the summary
summary = Chatbot_output2

# Define the max score for each metric
max_scores = {
    "Relevance": 5,
    "Coherence": 5,
    "Consistency": 5,
    "Fluency": 3,
}

# Store evaluation data
data = {"Evaluation Type": [], "Score": [], "Normalized Score": []}

# Evaluate the summary on each metric
for eval_type, (criteria, steps) in evaluation_metrics.items():
    data["Evaluation Type"].append(eval_type)
    result = get_geval_score(criteria, steps, database_retriever2, summary, eval_type)
    score_num = int(result.strip())
    max_score = max_scores[eval_type]
    fraction = round(score_num / max_score, 2)

    data["Score"].append(score_num)
    data["Normalized Score"].append(fraction)

# Create a DataFrame
eval_df = pd.DataFrame(data)

# Display results
print("\nG-Eval Evaluation Score :\n")
display(eval_df)
# Out:
# G-Eval Evaluation Score :
#   Evaluation Type  Score  Normalized Score
# 0       Relevance      5               1.0
# 1       Coherence      5               1.0
# 2     Consistency      5               1.0
# 3         Fluency      3               1.0

# %%
# Set the summary
summary = Chatbot_output3

# Define the max score for each metric
max_scores = {
    "Relevance": 5,
    "Coherence": 5,
    "Consistency": 5,
    "Fluency": 3,
}

# Store evaluation data
data = {"Evaluation Type": [], "Score": [], "Normalized Score": []}

# Evaluate the summary on each metric
for eval_type, (criteria, steps) in evaluation_metrics.items():
    data["Evaluation Type"].append(eval_type)
    result = get_geval_score(criteria, steps, database_retriever3, summary, eval_type)
    score_num = int(result.strip())
    max_score = max_scores[eval_type]
    fraction = round(score_num / max_score, 2)

    data["Score"].append(score_num)
    data["Normalized Score"].append(fraction)

# Create a DataFrame
eval_df = pd.DataFrame(data)

# Display results
print("\nG-Eval Evaluation Score :\n")
display(eval_df)
# Out:
# G-Eval Evaluation Score :
#   Evaluation Type  Score  Normalized Score
# 0       Relevance      5               1.0
# 1       Coherence      5               1.0
# 2     Consistency      5               1.0
# 3         Fluency      3               1.0

# %%
# Set the summary
summary = Chatbot_output4

# Define the max score for each metric
max_scores = {
    "Relevance": 5,
    "Coherence": 5,
    "Consistency": 5,
    "Fluency": 3,
}

# Store evaluation data
data = {"Evaluation Type": [], "Score": [], "Normalized Score": []}

# Evaluate the summary on each metric
for eval_type, (criteria, steps) in evaluation_metrics.items():
    data["Evaluation Type"].append(eval_type)
    result = get_geval_score(criteria, steps, database_retriever4, summary, eval_type)
    score_num = int(result.strip())
    max_score = max_scores[eval_type]
    fraction = round(score_num / max_score, 2)

    data["Score"].append(score_num)
    data["Normalized Score"].append(fraction)

# Create a DataFrame
eval_df = pd.DataFrame(data)

# Display results
print("\nG-Eval Evaluation Score :\n")
display(eval_df)
# Out:
# G-Eval Evaluation Score :
#   Evaluation Type  Score  Normalized Score
# 0       Relevance      5               1.0
# 1       Coherence      5               1.0
# 2     Consistency      5               1.0
# 3         Fluency      3               1.0

# %%
# Set the summary
summary = Chatbot_output5

# Define the max score for each metric
max_scores = {
    "Relevance": 5,
    "Coherence": 5,
    "Consistency": 5,
    "Fluency": 3,
}

# Store evaluation data
data = {"Evaluation Type": [], "Score": [], "Normalized Score": []}

# Evaluate the summary on each metric
for eval_type, (criteria, steps) in evaluation_metrics.items():
    data["Evaluation Type"].append(eval_type)
    result = get_geval_score(criteria, steps, database_retriever5, summary, eval_type)
    score_num = int(result.strip())
    max_score = max_scores[eval_type]
    fraction = round(score_num / max_score, 2)

    data["Score"].append(score_num)
    data["Normalized Score"].append(fraction)

# Create a DataFrame
eval_df = pd.DataFrame(data)

# Display results
print("\nG-Eval Evaluation Score :\n")
display(eval_df)
# Out:
# G-Eval Evaluation Score :
#   Evaluation Type  Score  Normalized Score
# 0       Relevance      5               1.0
# 1       Coherence      5               1.0
# 2     Consistency      5               1.0
# 3         Fluency      3               1.0

# %% [markdown]
# ### RAG-Evaluation (RAG_Eval)

# %%
# !pip install -q rag_evaluation

# import evaluate_response
from gpt_evaluation.evaluator import evaluate_response
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 22.1 MB/s eta 0:00:00

# %% [markdown]
# ### Evaluation

# %%
# use rag-eval

# Input strings
query = Query1
response = Chatbot_output1
document = database_retriever1

# Get evaluation results
evaluate_response(
        query,
        response,
        document,
        model="gpt-4",
    )
# Out:
#              Metric  Score (Normalized)  Score (%)
# 0   Query Relevance                 1.0      100.0
# 1  Factual Accuracy                 1.0      100.0
# 2          Coverage                 1.0      100.0
# 3         Coherence                 1.0      100.0
# 4           Fluency                 1.0      100.0
# 5  Overall Accuracy                 1.0      100.0

# %%
# use rag-eval

# Input strings
query = Query2
response = Chatbot_output2
document = database_retriever2

# Get evaluation results
evaluate_response(
        query,
        response,
        document,
        model="gpt-4",
    )
# Out:
#              Metric  Score (Normalized)  Score (%)
# 0   Query Relevance                 1.0      100.0
# 1  Factual Accuracy                 1.0      100.0
# 2          Coverage                 1.0      100.0
# 3         Coherence                 1.0      100.0
# 4           Fluency                 1.0      100.0
# 5  Overall Accuracy                 1.0      100.0

# %%
# use rag-eval

# Input strings
query = Query3
response = Chatbot_output3
document = database_retriever3

# Get evaluation results
evaluate_response(
        query,
        response,
        document,
        model="gpt-4",
    )
# Out:
#              Metric  Score (Normalized)  Score (%)
# 0   Query Relevance                 1.0      100.0
# 1  Factual Accuracy                 1.0      100.0
# 2          Coverage                 1.0      100.0
# 3         Coherence                 1.0      100.0
# 4           Fluency                 1.0      100.0
# 5  Overall Accuracy                 1.0      100.0

# %%
# use rag-eval

# Input strings
query = Query4
response = Chatbot_output4
document = database_retriever4

# Get evaluation results
evaluate_response(
        query,
        response,
        document,
        model="gpt-4",
    )
# Out:
#              Metric  Score (Normalized)  Score (%)
# 0   Query Relevance                1.00      100.0
# 1  Factual Accuracy                1.00      100.0
# 2          Coverage                0.80       80.0
# 3         Coherence                1.00      100.0
# 4           Fluency                1.00      100.0
# 5  Overall Accuracy                0.95       95.0

# %%
# use rag-eval

# Input strings
query = Query5
response = Chatbot_output5
document = database_retriever5

# Get evaluation results
evaluate_response(
        query,
        response,
        document,
        model="gpt-4",
    )
# Out:
#              Metric  Score (Normalized)  Score (%)
# 0   Query Relevance                1.00      100.0
# 1  Factual Accuracy                1.00      100.0
# 2          Coverage                0.80       80.0
# 3         Coherence                1.00      100.0
# 4           Fluency                1.00      100.0
# 5  Overall Accuracy                0.95       95.0

# %% [markdown]
# ## Query-Response Mismatch Evaluation

# %%
# use rag-eval

# Input strings
query = Query3
response = Chatbot_output1
document = database_retriever1

evaluate_response(
        query,
        response,
        document,
        model="gpt-4",
    )
# Out:
#              Metric  Score (Normalized)  Score (%)
# 0   Query Relevance                0.20       20.0
# 1  Factual Accuracy                1.00      100.0
# 2          Coverage                0.60       60.0
# 3         Coherence                0.80       80.0
# 4           Fluency                0.80       80.0
# 5  Overall Accuracy                0.65       65.0

# %%
# use rag-eval

# Input strings
query = Query1
response = Chatbot_output2
document = database_retriever2

evaluate_response(
        Query1,
        response,
        document,
        model="gpt-4",
    )
# Out:
#              Metric  Score (Normalized)  Score (%)
# 0   Query Relevance               0.200       20.0
# 1  Factual Accuracy               1.000      100.0
# 2          Coverage               0.200       20.0
# 3         Coherence               0.800       80.0
# 4           Fluency               1.000      100.0
# 5  Overall Accuracy               0.575       57.5

# %%
# use rag-eval

# Input strings
query = Query1
response = Chatbot_output3
document = database_retriever3

# Get evaluation results
evaluate_response(
        query,
        response,
        document,
        model="gpt-4",
    )
# Out:
#              Metric  Score (Normalized)  Score (%)
# 0   Query Relevance               0.200       20.0
# 1  Factual Accuracy               1.000      100.0
# 2          Coverage               0.600       60.0
# 3         Coherence               0.800       80.0
# 4           Fluency               1.000      100.0
# 5  Overall Accuracy               0.675       67.5

# %%
# use rag-eval

# Input strings
query = 'Could you please give me update on the latest contract on Transportation'
response = Chatbot_output4
document = database_retriever4

evaluate_response(
        query,
        response,
        document,
        model="gpt-4"
    )
# Out:
#              Metric  Score (Normalized)  Score (%)
# 0   Query Relevance               0.200       20.0
# 1  Factual Accuracy               0.800       80.0
# 2          Coverage               0.600       60.0
# 3         Coherence               0.800       80.0
# 4           Fluency               1.000      100.0
# 5  Overall Accuracy               0.625       62.5

# %%
# use rag-eval


# Input strings
query = Query1
response = Chatbot_output5
document = database_retriever5

evaluate_response(
        Query1,
        response,
        document,
        model="gpt-4",
    )
# Out:
#              Metric  Score (Normalized)  Score (%)
# 0   Query Relevance               0.200       20.0
# 1  Factual Accuracy               1.000      100.0
# 2          Coverage               0.600       60.0
# 3         Coherence               0.800       80.0
# 4           Fluency               1.000      100.0
# 5  Overall Accuracy               0.675       67.5

# %% [markdown]
# ## Factual Consistency Evaluation

# %%
# use rag-eval

# Input strings
query = Query1
response = """Pull tester training focuses on the safe and effective use of pull testing
            equipment to measure tensile strength, adhesion, or load-bearing capacity. It includes
            understanding testing principles, equipment setup, calibration, safety protocols, data interpretation,
            and troubleshooting techniques. Participants gain hands-on experience to ensure accurate
            and consistent results across industries."""
document = database_retriever1

# Get evaluation results
evaluate_response(
        query,
        response,
        document,
        model="gpt-4",
    )
# Out:
#              Metric  Score (Normalized)  Score (%)
# 0   Query Relevance               0.400       40.0
# 1  Factual Accuracy               0.200       20.0
# 2          Coverage               0.200       20.0
# 3         Coherence               0.400       40.0
# 4           Fluency               1.000      100.0
# 5  Overall Accuracy               0.375       37.5

# %%
# use rag-eval

# Input strings
query = Query2
response = """An email ID, or email address, is a unique identifier used to send and receive electronic messages.
              It typically comprises a local part (username) and a domain part (e.g., example.com). The specific email ID "123456789"
              appears to be a numeric sequence, which is uncommon for standard email addresses. Without additional context, it's
              challenging to provide detailed information about this particular identifier."""
document = database_retriever2

# Get evaluation results
evaluate_response(
    query,
    response,
    document,
    model="gpt-4",
)
# Out:
#              Metric  Score (Normalized)  Score (%)
# 0   Query Relevance                 0.2       20.0
# 1  Factual Accuracy                 0.2       20.0
# 2          Coverage                 0.2       20.0
# 3         Coherence                 0.2       20.0
# 4           Fluency                 1.0      100.0
# 5  Overall Accuracy                 0.3       30.0

# %%
# use rag-eval

# Input strings
query = Query3
response = """In Stevenage, various venues offer online diary booking systems to streamline reservations.
              The Stevenage Arts Guild provides an online booking diary for its Arts Centre, accessible to registered users.
              Similarly, the Roebuck Inn allows guests to book accommodations through its online platform. These systems
              enhance efficiency and user experience."""
document = database_retriever3

# Get evaluation results
evaluate_response(
    query,
    response,
    document,
    model="gpt-4",
)
# Out:
#              Metric  Score (Normalized)  Score (%)
# 0   Query Relevance                 0.2       20.0
# 1  Factual Accuracy                 0.2       20.0
# 2          Coverage                 0.2       20.0
# 3         Coherence                 0.2       20.0
# 4           Fluency                 1.0      100.0
# 5  Overall Accuracy                 0.3       30.0
